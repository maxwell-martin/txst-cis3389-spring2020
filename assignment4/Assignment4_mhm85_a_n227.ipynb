# %%
# Assignment 4 - Maxwell Martin and Anam Nawab

import pandas as pd

# %%
# a.
df = pd.read_csv("Eng_salaries.csv")
df
# Out:
#               Rank Discipline  YearsSinceDegree  YearsOfService  Gender  \
# 0          Manager          B                56              49    Male
# 1          Manager          A                12               6    Male
# 2          Manager          A                23              20    Male
# 3          Manager          A                40              31    Male
# 4          Manager          B                20              18    Male
# ..             ...        ...               ...             ...     ...
# 73         Manager          B                18              10  Female
# 74  SeniorEngineer          B                19               6  Female
# 75         Manager          B                17              17  Female
# 76         Manager          A                28              14  Female
# 77         Manager          A                23              15  Female
#
#     Salary
# 0   186960
# 1    93000
# 2   110515
# 3   131205
# 4   104800
# ..     ...
# 73  105450
# ...

# %%
# b.
df.shape
# Out:
# (78, 6)

# %%
df.size
# Out:
# 468

# %%
# c.
df.head(10)
# Out:
#              Rank Discipline  YearsSinceDegree  YearsOfService Gender  Salary
# 0         Manager          B                56              49   Male  186960
# 1         Manager          A                12               6   Male   93000
# 2         Manager          A                23              20   Male  110515
# 3         Manager          A                40              31   Male  131205
# 4         Manager          B                20              18   Male  104800
# 5         Manager          A                20              20   Male  122400
# 6  SeniorEngineer          A                20              17   Male   81285
# 7         Manager          A                18              18   Male  126300
# 8         Manager          A                29              19   Male   94350
# 9         Manager          A                51              51   Male   57800

# %%
# d.
df.sample(5)
# Out:
#               Rank Discipline  YearsSinceDegree  YearsOfService  Gender  \
# 5          Manager          A                20              20    Male
# 9          Manager          A                51              51    Male
# 64  SeniorEngineer          A                26              24  Female
# 74  SeniorEngineer          B                19               6  Female
# 40         Manager          A                39              36  Female
#
#     Salary
# 5   122400
# 9    57800
# 64   73300
# 74  104542
# 40  137000

# %%
# e.
df = df.drop("Discipline", axis = 1)
df
# Out:
#               Rank  YearsSinceDegree  YearsOfService  Gender  Salary
# 0          Manager                56              49    Male  186960
# 1          Manager                12               6    Male   93000
# 2          Manager                23              20    Male  110515
# 3          Manager                40              31    Male  131205
# 4          Manager                20              18    Male  104800
# ..             ...               ...             ...     ...     ...
# 73         Manager                18              10  Female  105450
# 74  SeniorEngineer                19               6  Female  104542
# 75         Manager                17              17  Female  124312
# 76         Manager                28              14  Female  109954
# 77         Manager                23              15  Female  109646
#
# [78 rows x 5 columns]

# %%
# f.
df["Salary"].dtype
# Out:
# dtype('int64')

# %%
# g.
df.ndim
# Out:
# 2

# %%
# h.
df.shape # Original shape of data frame: 78 rows and 5 columns
# Out:
# (78, 5)

# %%
df = df.dropna() # Drop the rows with missing values.

# %%
df.shape # New shape of data frame after dropping rows with na values: 78 rows and 5 columns

# No rows were dropped. There are no rows with missing values.
# Out:
# (78, 5)

# %%
# i.
df.describe()
# Out:
#        YearsSinceDegree  YearsOfService         Salary
# count         78.000000       78.000000      78.000000
# mean          19.705128       15.051282  108023.782051
# std           12.498425       12.139768   28293.661022
# min            1.000000        0.000000   57800.000000
# 25%           10.250000        5.250000   88612.500000
# 50%           18.500000       14.500000  104671.000000
# 75%           27.750000       20.750000  126774.750000
# max           56.000000       51.000000  186960.000000

# %%
# j.
grouped = df['Salary'].groupby(df['Rank'])
grouped.mean()
# Out:
# Rank
# JuniorEngineer     81362.789474
# Manager           123624.804348
# SeniorEngineer     91786.230769
# Name: Salary, dtype: float64

# %%
# k.
grouped.sum()
# Out:
# Rank
# JuniorEngineer    1545893
# Manager           5686741
# SeniorEngineer    1193221
# Name: Salary, dtype: int64

# %%
# l.
df[['Salary','YearsOfService']].agg(['min','mean', 'max'])
# Out:
#              Salary  YearsOfService
# min    57800.000000        0.000000
# mean  108023.782051       15.051282
# max   186960.000000       51.000000

# %%
# m.
df.loc[10:25, ["Rank", "YearsSinceDegree", "Salary"]] # YearsSincePhd is not a column name. It should be YearsSinceDegree.
# Out:
#               Rank  YearsSinceDegree  Salary
# 10         Manager                39  128250
# 11         Manager                23  134778
# 12  JuniorEngineer                 1   88000
# 13         Manager                35  162200
# 14         Manager                25  153750
# 15         Manager                17  150480
# 16  JuniorEngineer                 8   75044
# 17  JuniorEngineer                 4   92000
# 18         Manager                19  107300
# 19         Manager                29  150500
# 20  JuniorEngineer                 4   92000
# 21         Manager                33  103106
# 22  JuniorEngineer                 4   73000
# 23  JuniorEngineer                 2   85000
# 24         Manager                30   91100
# 25         Manager                35   99418

# %%
# n.
df["YearsOfService"].corr(df["Salary"])
# Out:
# 0.5321913486037866

# %%
# o.
df2 = df[df["Salary"] < 100000]
df2
# Out:
#               Rank  YearsSinceDegree  YearsOfService  Gender  Salary
# 1          Manager                12               6    Male   93000
# 6   SeniorEngineer                20              17    Male   81285
# 8          Manager                29              19    Male   94350
# 9          Manager                51              51    Male   57800
# 12  JuniorEngineer                 1               0    Male   88000
# 16  JuniorEngineer                 8               3    Male   75044
# 17  JuniorEngineer                 4               0    Male   92000
# 20  JuniorEngineer                 4               4    Male   92000
# 22  JuniorEngineer                 4               2    Male   73000
# 23  JuniorEngineer                 2               0    Male   85000
# 24         Manager                30              23    Male   91100
# 25         Manager                35              31    Male   99418
# 28  JuniorEngineer                 7               2    Male   91300
# ...

# %%
df2.shape
# Out:
# (32, 5)

# %%
# p.
df2["Salary_square"] = df2["Salary"] ** 2
df2
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#               Rank  YearsSinceDegree  YearsOfService  Gender  Salary  \
# 1          Manager                12               6    Male   93000
# 6   SeniorEngineer                20              17    Male   81285
# 8          Manager                29              19    Male   94350
# 9          Manager                51              51    Male   57800
# 12  JuniorEngineer                 1               0    Male   88000
# 16  JuniorEngineer                 8               3    Male   75044
# 17  JuniorEngineer                 4               0    Male   92000
# ...

# %%
# q.
df.sort_values(by = "Salary", ascending = False)
# Out:
#               Rank  YearsSinceDegree  YearsOfService  Gender  Salary
# 0          Manager                56              49    Male  186960
# 13         Manager                35              33    Male  162200
# 72         Manager                24              15  Female  161101
# 27         Manager                45              43    Male  155865
# 31         Manager                22              21    Male  155750
# ..             ...               ...             ...     ...     ...
# 55  JuniorEngineer                 2               0  Female   72500
# 71  SeniorEngineer                12               9  Female   71065
# 66  JuniorEngineer                 7               6  Female   63100
# 54  SeniorEngineer                25              22  Female   62884
# 9          Manager                51              51    Male   57800
#
# [78 rows x 5 columns]

# %%
from matplotlib import pyplot as plt

# r.
plt.bar(df['Rank'],df['YearsSinceDegree'], color = "g")
plt.title('YearsSinceDegree compared to Rank')
plt.xlabel('Rank')
plt.ylabel('Years')

# The first bar ("Manager") has the maximum height.
# Out:
# Text(0, 0.5, 'Years')

# %%
# s.
plt.bar(df['Gender'],df['Salary'], color = "r")
plt.title('Salary compared by Gender')
plt.xlabel('Gender')
plt.ylabel('Salary')

# Males have a higher salary.
# Out:
# Text(0, 0.5, 'Salary')

# %%
# t.
df['Gender'] = df['Gender'].map({'Male': 1, 'Female': 0})
df
# Out:
#               Rank  YearsSinceDegree  YearsOfService  Gender  Salary
# 0          Manager                56              49       1  186960
# 1          Manager                12               6       1   93000
# 2          Manager                23              20       1  110515
# 3          Manager                40              31       1  131205
# 4          Manager                20              18       1  104800
# ..             ...               ...             ...     ...     ...
# 73         Manager                18              10       0  105450
# 74  SeniorEngineer                19               6       0  104542
# 75         Manager                17              17       0  124312
# 76         Manager                28              14       0  109954
# 77         Manager                23              15       0  109646
#
# [78 rows x 5 columns]
