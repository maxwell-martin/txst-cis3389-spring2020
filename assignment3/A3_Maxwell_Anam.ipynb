# %%
# Assignment 3 - Web Scraping - Maxwell Martin and Anam Nawab

# Relevant modules for scraping.
from bs4 import BeautifulSoup
import pandas as pd
import requests

# Url of page to scrape.
url = "https://www.ebay.com/sch/i.html?_from=R40&_trksid=p2334524.m570.l1313.TR12.TRC2.A0.H0.Xmouse.TRS0&_nkw=mouse&_sacat=0&LH_TitleDesc=0&_osacat=0&_odkw=laptop"

# Make HTTP request for page.
page = requests.get(url)

# Confirm we get a valid HTTP response.
print(page)
# Out:
# <Response [200]>

# %%
# Convert page HTML to a BeautifulSoup object.
soup = BeautifulSoup(page.content, 'html.parser')

# Confirm soup object contains page's HTML.
print(soup)
# Out:
# <!DOCTYPE html>
# ...

# %%
# Get all product names.
product_names_h3s = soup.find_all(class_="s-item__title")

# Get all the product conditions.
product_conditions_spans = soup.find_all(class_="SECONDARY_INFO")

# Get all product prices.
product_prices_spans = soup.find_all(class_="s-item__price")

# Confirm we got the same number of items for each list and the number matches the number of items shown on the page.
print(len(product_names_h3s))
print(len(product_conditions_spans))
print(len(product_prices_spans))
# Out:
# 63
# 63
# 63

# %%
# Create list of product names.
product_names = []
for h3 in product_names_h3s:
    print(h3.text)
    product_names.append(h3.text.strip())
    
# Confirm list has all product conditions.
print(product_names)
# Out:
# 2.4GHz Wireless Optical Mouse Mice & USB Receiver For PC Laptop Computer DPI USA
# 2.4GHz High Quality Wireless Optical Mouse/Mice + USB 2.0 Receiver for PC Laptop
# 2.4GHz USB Wireless Optical Mouse Mice for Apple Mac Macbook Pro Air PC White
# 2.4GHz Rechargeable Wireless Mouse USB Receiver Mice For Computer PC Laptop
# Big Sale Gaming Mouse Alternating Light USB 2.0 7-Button Optical Wired Mice
# 2.4GHz Wireless Optical Mouse Adjustable DPI Cordless Mice + Receiver for Laptop
# JETech M2260 Bluetooth Wireless Mouse for PC, Mac, and Android OS Tablet
# Wired USB Optical Mouse Wireless Optical Mouse Retractable Mini USB Mouse For PC
# 2.4GHz Cordless Wireless Optical Mouse Mice For Laptop PC Computer  4 colors US
# Lenovo Essential USB Wired Optical Mouse BLACK P/N ooPH133 NEW
# 2.4GHz Wireless Optical Mouse Mice & USB Receiver For PC Laptop Computer DPI USA
# Philips SPK7214 USB Wired Computer Mouse for PC Laptop Desktop Computers
# ...

# %%
# Create list of product conditions.
product_conditions = []
for span in product_conditions_spans:
    print(span.text)
    product_conditions.append(span.text.strip())
    
# Confirm list contains all product conditions.
print(product_conditions)
# Out:
# Brand New
# Brand New
# Brand New
# Brand New
# Brand New
# Brand New
# Brand New
# Brand New
# Brand New
# Brand New
# Brand New
# Brand New
# Brand New
# Brand New
# Brand New
# Brand New
# Brand New
# Brand New
# Brand New
# Refurbished
# Brand New
# Brand New
# Brand New
# Brand New
# Brand New
# Brand New
# Brand New
# Brand New
# Pre-Owned
# Brand New
# Brand New
# Brand New
# Open Box
# Brand New
# Brand New
# Pre-Owned
# Brand New
# Open Box
# Brand New
# Brand New
# Brand New
# Brand New
# Brand New
# Brand New
# Brand New
# Brand New
# Brand New
# Brand New
# Brand New
# Brand New
# Brand New
# Brand New
# Brand New
# Pre-Owned
# Brand New
# Brand New
# Brand New
# Brand New
# Brand New
# Brand New
# Brand New
# Brand New
# Brand New
# ...

# %%
# Create list of product prices.
product_prices = []
for span in product_prices_spans:
    print(span.text)
    product_prices.append(span.text.strip())
    
# Confirm list contains all product conditions.
print(product_prices)
# Out:
# $1.99
# $7.99 to $12.99
# $6.95
# $11.59 to $12.95
# $5.99
# $6.99
# $6.99
# $4.25 to $7.99
# $5.63
# $6.99
# $6.99
# $6.99
# $6.99
# $10.49
# $7.99
# $10.97
# $14.98
# $9.20 to $18.20
# $6.75
# $12.98
# $39.99
# $5.99
# $10.97
# $10.99 to $16.99
# $4.99
# $7.99
# $12.99
# $11.99
# $11.73
# $5.37
# $7.99
# $13.57
# $24.99
# $12.98
# $10.09
# $21.99
# $12.99
# $25.00
# $6.95 to $13.85
# $12.98
# $10.99
# $10.99
# $62.99
# $9.99
# $9.99 to $10.79
# $5.93
# $8.99
# $7.69
# $49.99
# $14.99
# $11.99
# $9.99
# $12.97
# $9.95
# $11.99
# $29.95
# $10.99
# $11.80
# $5.93
# $14.99
# $9.19
# $7.19
# $7.25
# ...

# %%
# Create Pandas data frame.
products = pd.DataFrame( { "Product Name": product_names, 
                           "Product Condition": product_conditions, 
                           "Product Price": product_prices } )

# Confirm data frame is setup properly.
print(products)

# Export data frame to a csv file.
csv = products.to_csv("ebay_products.csv", index = None, header = True)
# Out:
#                                          Product Name Product Condition  \
# 0   2.4GHz Wireless Optical Mouse Mice & USB Recei...         Brand New
# 1   2.4GHz High Quality Wireless Optical Mouse/Mic...         Brand New
# 2   2.4GHz USB Wireless Optical Mouse Mice for App...         Brand New
# 3   2.4GHz Rechargeable Wireless Mouse USB Receive...         Brand New
# 4   Big Sale Gaming Mouse Alternating Light USB 2....         Brand New
# ..                                                ...               ...
# 58  2.4GHz Wireless DPI Cordless Optical Mouse Mic...         Brand New
# 59  Logitech M325c Wireless Compact Size Optical M...         Brand New
# 60  2.4GHz Wireless Cordless Optical Gaming Mouse ...         Brand New
# 61  2.4GHz Wireless Cordless Optical Mouse Mice US...         Brand New
# 62  🔥Gaming Mouse 7 Button USB Wired LED Breathing...         Brand New
#
#        Product Price
# 0              $1.99
# 1    $7.99 to $12.99
# 2              $6.95
# ...
